# %%
import pandas as pd
df=pd.read_csv("sample_data/BIKE SALE.csv.csv")

# %%
import numpy as np

# %%
Year=np.array(df['MODEL YEAR'])

# %%
np.sum(Year)
# Out:
# 20203

# %%
import pandas as pd

# %%
data=pd.Series([0.25,0.5,0.75,1.0],index=['A','B',32,65])

# %%
data
# Out:
# A     0.25
# B     0.50
# 32    0.75
# 65    1.00
# dtype: float64

# %%
id={'hashim':1,'Yatish':2,'Ashmi':3}

# %%
data1=pd.Series(id)
data1
# Out:
# hashim    1
# Yatish    2
# Ashmi     3
# dtype: int64

# %%
marks={'hashim':100,'Yatish':98,'Ashmi':70}

# %%
data2=pd.DataFrame({'id':id,'marks':marks})
data2
# Out:
#         id  marks
# hashim   1    100
# Yatish   2     98
# Ashmi    3     70

# %%
data=pd.Series([1,np.nan,'hello',None])
data.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# dtype: bool

# %%
data.notnull()
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
data.dropna()
# Out:
# 0        1
# 2    hello
# dtype: object

# %%
df=pd.DataFrame([[1,np.nan,2],[2,3,4],[np.nan,4,6]])

# %%
df
# Out:
#      0    1  2
# 0  1.0  NaN  2
# 1  2.0  3.0  4
# 2  NaN  4.0  6

# %%
df.dropna()
# Out:
#      0    1  2
# 1  2.0  3.0  4

# %%
df.fillna(0)
# Out:
#      0    1  2
# 0  1.0  0.0  2
# 1  2.0  3.0  4
# 2  0.0  4.0  6

# %%
f1=pd.DataFrame(
    {"A":["A0","A1","A2","A3"],
     "B":["B0","B1","B2","B3"],
     "C":["C0","C1","C2","C3"],
     "D":["D0","D1","D2","D3"],
     },
     index=[0,1,2,3],
)

# %%
f2=pd.DataFrame(
     {
         "A":["A4","A5","A6","A7"],
         "B":["B4","B5","B6","B7"],
         "C":["C4","C5","C6","C7"],
         "D":["D4","D5","D6","D7"],
     },
     index=[0,1,2,3],

)

# %%
frames=[f1,f2]
res=pd.concat(frames)
res
