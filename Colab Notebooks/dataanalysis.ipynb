# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("unclean_data.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-23-6c3a7869ee19> in <module>
# ----> 1 df=pd.read_csv("unclean_data.csv")
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df1=pd.read_csv("unclean_data.csv",encoding="latin1")

# %%
df1.head()
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %%
df1.isnull().sum().sum()
# Out:
# 21

# %%
df_with_0=df1.fillna(0)

# %%
df_with_0.head()
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      10                     855
# 1       0.0                     563                    1000
# 2     148.0                      20                     161
# 3       0.0                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %%
df1.mean()
# Out:
# <ipython-input-36-00fb6bfec183>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.mean()
# num_critic_for_reviews       5.061429e+02
# duration                     1.507273e+02
# actor_3_facebook_likes       5.866143e+03
# ACTOR_1_facebook_likes       1.820643e+04
# gross                        3.335836e+08
# num_voted_users              4.621578e+05
# Cast_Total_facebook_likes    4.477358e+04
# facenumber_in_poster         2.111111e+00
# num_user_for_reviews         1.620071e+03
# budget                       2.462643e+08
# title_year                   2.010500e+03
# ACTOR_2_facebook_likes       8.455846e+03
# imdb_score                   7.171429e+00
# title_year.1                 2.011143e+03
# dtype: float64

# %%
df1.shape
# Out:
# (14, 16)

# %%
df1_drop=df1.dropna()

# %%
df1_drop.shape
# Out:
# (4, 16)

# %%
df=pd.read_csv("unclean_data1.csv",encoding='utf8')

# %%
df.duplicated(['movie_title'])
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# dtype: bool

# %%
df.shape
# Out:
# (14, 16)

# %%
df_drop_dup=df.drop_duplicates('movie_title')

# %%
df.dtypes
# Out:
# movie_title                   object
# num_critic_for_reviews         int64
# duration                     float64
# DIRECTOR_facebook_likes       object
# actor_3_facebook_likes         int64
# ACTOR_1_facebook_likes         int64
# gross                          int64
# num_voted_users              float64
# Cast_Total_facebook_likes    float64
# facenumber_in_poster         float64
# num_user_for_reviews           int64
# budget                         int64
# title_year                     int64
# ACTOR_2_facebook_likes       float64
# imdb_score                   float64
# title_year.1                 float64
# dtype: object

# %%
df=pd.read_csv('unclean_data1.csv',dtype={'num_critic_for_reviews':float})

# %%
df.duration+ df.gross
# Out:
# 0     760506025.0
# 1             NaN
# 2     200074323.0
# 3             NaN
# 4      73058811.0
# 5     336530459.0
# 6             NaN
# 7     458991740.0
# 8     458991740.0
# 9     301957133.0
# 10    330249245.0
# 11    200069577.0
# 12    168368533.0
# 13    423032779.0
# dtype: float64

# %%
df.movie_title  +"_"+ df.DIRECTOR_facebook_likes
# Out:
# 0                                          Avatar?ÿ_10
# 1       Pirates of the Caribbean: At World's End?ÿ_563
# 2                                         Spectre?ÿ_20
# 3                        The Dark Knight Rises?ÿ_22000
# 4                                  John Carter?ÿ_"475"
# 5                                    Spider-Man 3?ÿ_23
# 6                                         Tangled?ÿ_15
# 7                         Avengers: Age of Ultron?ÿ_10
# 8                         Avengers: Age of Ultron?ÿ_10
# 9         Harry Potter and the Half-Blood Prince?ÿ_282
# 10                                                 NaN
# 11                                                 NaN
# 12                             Quantum of Solace?ÿ_395
# 13    Pirates of the Caribbean: Dead Man's Chest?ÿ_563
# dtype: object

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
array1=[1,2,3,4]
array2=[2,5,7,8]
plt.plot(array1,array2)
plt.show()

# %%
plt.style.use('classic')
fig, ax =plt.subplots(2)
x=[1,2,3,4,5]
ax[0].plot(x,np.sin(x))
ax[1].plot(x,np.cos(x));
